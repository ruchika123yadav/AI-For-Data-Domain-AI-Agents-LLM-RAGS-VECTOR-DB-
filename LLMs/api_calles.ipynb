# %% [markdown]
# GOOGLE GENAI SDK

# %%
from google import genai
import os
from dotenv import load_dotenv

# 1. .env file ko load karo
load_dotenv()

client = genai.Client(api_key=GEMINI_API_KEY)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Explain how AI works in a few words"
)
print(interaction.output_text)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_sync\connection.py:156, in HTTPConnection._connect(self, request)
#     155 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156     stream = stream.start_tls(**kwargs)
#     157     trace.return_value = stream
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_backends\sync.py:154, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     150 exc_map: ExceptionMapping = {
#     151     socket.timeout: ConnectTimeout,
#     152     OSError: ConnectError,
#     153 }
# --> 154 with map_exceptions(exc_map):
#     155     try:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\basesdk.py:258, in BaseSDK.do_request.<locals>.do(_attempt)
#     256         raise ValueError("client is required")
# --> 258     http_res = client.send(req, stream=stream)
#     259 except Exception as e:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[3], line 10
#       6 load_dotenv()
#       7
#       8 client = genai.Client(api_key="AQ.Ab8RN6JDDA7ut7aG4fstZLu-Y0IqGu3KzxAXRyb6aZqR7iwneA")
#       9
# ---> 10 interaction = client.interactions.create(
#      11     model="gemini-3.5-flash",
#      12     input="Explain how AI works in a few words"
#      13 )
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\google_genai.py:271, in GeminiNextGenInteractions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body)
#     269 stream = _optional_bool(body.get('stream'), default=False)
#     270 body = _normalize_create_body(body)
# --> 271 response = wrap_sdk_call(
#     272     super().create,
#     273     api_version=api_version,
#     274     **cast(Any, body),
#     275     extra_headers=extra_headers,
#     276     extra_query=extra_query,
#     277     extra_body=extra_body,
#     278     timeout=timeout,
#     279 )
#     280 if stream:
#     281     if is_stream(response):
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\lib\compat_errors.py:348, in wrap_sdk_call(fn, *args, **kwargs)
#     346 """Execute `fn(*args, **kwargs)`, translating known SDK exceptions."""
#     347 try:
# --> 348     return fn(*args, **kwargs)
#     349 except _WRAP_EXCEPTIONS as exc:
#     350     raise wrap_sdk_error(exc) from exc
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\interactions.py:532, in Interactions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body_kwargs)
#     518     raise errors.GenAiDefaultError(
#     519         "Unexpected response received", http_res, http_res_text
#     520     )
#     522 _speakeasy_hook_ctx = HookContext(
#     523     config=self.sdk_configuration,
#     524     base_url=base_url or "",
#    (...)    530     response=ResponseContext(mode=_speakeasy_response_mode, execution="sync"),
#     531 )
# --> 532 http_res = self.do_request(
#     533     hook_ctx=_speakeasy_hook_ctx,
#     534     request=req,
#     535     is_error_status_code=lambda c: utils.match_status_codes(["4XX", "5XX"], c),
#     536     stream=getattr(getattr(request, "body", None), "stream", False) is True
#     537     or _speakeasy_response_mode == "streaming",
#     538     retry_config=retry_config,
#     539 )
#     540 if _speakeasy_response_mode != "parsed":
#     541     _speakeasy_response_cls = (
#     542         response_helpers.StreamedAPIResponse
#     543         if _speakeasy_response_mode == "streaming"
#     544         else response_helpers.APIResponse
#     545     )
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\basesdk.py:280, in BaseSDK.do_request(self, hook_ctx, request, is_error_status_code, stream, retry_config)
#     277     return http_res
#     279 if retry_config is not None:
# --> 280     http_res = utils.retry(do, utils.Retries(retry_config[0], retry_config[1]))
#     281 else:
#     282     http_res = do()
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\utils\retries.py:253, in retry(func, retries)
#     251     backoff = retries.config.backoff or BackoffStrategy(500, 60000, 1.5, 3600000)
#     252     if retries.config.strategy == "attempt-count-backoff":
# --> 253         return retry_with_attempt_count_backoff(
#     254             do_request,
#     255             backoff.initial_interval,
#     256             backoff.max_interval,
#     257             backoff.exponent,
#     258             retries.config.max_retries or 0,
#     259             backoff.jitter_ms,
#     260         )
#     262     return retry_with_backoff(
#     263         do_request,
#     264         backoff.initial_interval,
#    (...)    268         backoff.jitter_ms,
#     269     )
#     271 return func(0)
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\utils\retries.py:388, in retry_with_attempt_count_backoff(func, initial_interval, max_interval, exponent, max_retries, jitter_ms)
#     386     return func(retries)
#     387 except PermanentError as exception:
# --> 388     raise exception.inner
#     389 except Exception as exception:  # pylint: disable=broad-exception-caught
#     390     if retries >= max_retries:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\utils\retries.py:220, in retry.<locals>.do_request(attempt)
#     218 res: httpx.Response
#     219 try:
# --> 220     res = func(attempt)
#     222     should_retry = False
#     223     for code in retries.status_codes:
#
# File c:\Users\2462000\OneDrive - Cognizant\Desktop\AI_DATA\AI-For-Data-Domain-AI-Agents-LLM-RAGS-VECTOR-DB-\.venv\Lib\site-packages\google\genai\_gaos\basesdk.py:263, in BaseSDK.do_request.<locals>.do(_attempt)
#     261     if e is not None:
#     262         logger.debug("Request Exception", exc_info=True)
# --> 263         raise e
#     265 if http_res is None:
#     266     logger.debug("Raising no response SDK error")
#
# APIConnectionError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
